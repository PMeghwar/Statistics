# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Read Car_Sales.csv Data

# %%
dataset = pd.read_csv('/content/car_sales.csv')
df = pd.DataFrame(dataset)

# %% [markdown]
# ### Shape of Data

# %%
df.shape   #dataset has 157 rows and 16 columns
# Out:
# (157, 16)

# %% [markdown]
# ## Let's Explore the data

# %% [markdown]
# ### Basic information about the dataset and data types

# %%
df.head(5)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Manufacturer            30
# Model                  156
# Sales_in_thousands     157
# __year_resale_value    117
# Vehicle_type             2
# Price_in_thousands     152
# Engine_size             31
# Horsepower              66
# Wheelbase               88
# Width                   78
# Length                 127
# Curb_weight            147
# Fuel_capacity           55
# Fuel_efficiency         20
# Latest_Launch          130
# Power_perf_factor      154
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %% [markdown]
# Prior to summary statistics, identify missing values or duplicates and drop them.

# %% [markdown]
# ### Missing values

# %%
df.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
print('Data type:', df['__year_resale_value'].dtype)
df['__year_resale_value']= df['__year_resale_value'].fillna(df['__year_resale_value'].median())
print('Missing values:', df['__year_resale_value'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Engine_size'].dtype)
df['Engine_size'] = df['Engine_size'].fillna(df['Engine_size'].median())
print('Missing values:', df['Engine_size'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Price_in_thousands'].dtype)
df['Price_in_thousands'] = df['Price_in_thousands'].fillna(df['Price_in_thousands'].median())
print('Missing values:', df['Price_in_thousands'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Horsepower'].dtype)
df['Horsepower'] = df['Horsepower'].fillna(df['Horsepower'].median())
print('Missing values:', df['Horsepower'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Wheelbase'].dtype)
df['Wheelbase'] = df['Wheelbase'].fillna(df['Wheelbase'].median())
print('Missing values:', df['Wheelbase'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Length'].dtype)
df['Length'] = df['Length'].fillna(df['Length'].median())
print('Missing values:', df['Length'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Width'].dtype)
df['Width'] = df['Width'].fillna(df['Width'].median())
print('Missing values:', df['Width'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Length'].dtype)
df['Length'] = df['Length'].fillna(df['Length'].median())
print('Missing values:', df['Length'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Length'].dtype)
df['Length'] = df['Length'].fillna(df['Length'].median())
print('Missing values:', df['Length'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Curb_weight'].dtype)
df['Curb_weight'] = df['Curb_weight'].fillna(df['Curb_weight'].median())
print('Missing values:', df['Curb_weight'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Fuel_capacity'].dtype)
df['Fuel_capacity'] = df['Fuel_capacity'].fillna(df['Fuel_capacity'].median())
print('Missing values:', df['Fuel_capacity'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Fuel_efficiency'].dtype)
df['Fuel_efficiency'] = df['Fuel_efficiency'].fillna(df['Fuel_efficiency'].median())
print('Missing values:', df['Fuel_efficiency'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
print('Data type:', df['Power_perf_factor'].dtype)
df['Power_perf_factor'] = df['Power_perf_factor'].fillna(df['Power_perf_factor'].median())
print('Missing values:', df['Power_perf_factor'].isna().sum())
# Out:
# Data type: float64
# Missing values: 0

# %%
df.isna().sum()    #after removing missing values
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Check Duplicates

# %%
print("Number of duplicates: ", df.duplicated().sum())
# Out:
# Number of duplicates:  0

# %% [markdown]
# ### Keep only numeric columns in a dataframe
#
# hint: (use function select_dtype)

# %%
numeric_df = df.select_dtypes(include = 'number')

# %%
numeric_df.shape  #after removing non numeric columns we have 157 rows and 12 columns
# Out:
# (157, 12)

# %% [markdown]
# ### Summary statistics

# %%
numeric_df.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           157.000000          157.000000
# mean            52.998076            17.180318           27.332261
# std             68.029422            10.178562           14.268713
# min              0.110000             5.160000            9.235000
# 25%             14.114000            12.545000           18.145000
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            18.140000           31.930000
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   157.000000  157.000000  157.000000  157.000000  157.000000
# mean      3.060510  185.894904  107.484076   71.146178  187.347134
# std       1.041311   56.522319    7.616872    3.441124   13.388708
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %% [markdown]
# ## Distribution

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data=numeric_df)
plt.xticks(rotation=45)
plt.title('Box Plot of Numeric Columns')
plt.show()

# %% [markdown]
# ## Normalized Distribution (Gaussian)

# %%
sns.distplot(numeric_df)
# Out:
# <ipython-input-33-d4905771bea5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numeric_df)
# <Axes: ylabel='Density'>

# %%
# Select numeric columns (assuming all columns are numeric)
numeric_columns = numeric_df.columns

# Create a histogram for each numeric column
for col in numeric_columns:
  plt.hist(df[col])
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.title('Distribution of ' + col)
  plt.grid(True)
  plt.show()

# %% [markdown]
# ## Skewed Distribution (negative and positive)

# %%
for col in numeric_df:
    skewness = numeric_df[col].skew()
    print(f"Skewness of '{col}': {skewness}")

#Here we have only one column Length whose skewness is negative,
# Out:
# Skewness of 'Sales_in_thousands': 3.408518366470572
# Skewness of '__year_resale_value': 2.7596078613149624
# Skewness of 'Price_in_thousands': 1.7853991263500237
# Skewness of 'Engine_size': 1.1049946829756925
# Skewness of 'Horsepower': 1.0064919298234107
# Skewness of 'Wheelbase': 0.9741771849319394
# Skewness of 'Width': 0.48857960000426515
# Skewness of 'Length': -0.060034999150741744
# Skewness of 'Curb_weight': 0.7148020333191302
# Skewness of 'Fuel_capacity': 1.143576428561609
# Skewness of 'Fuel_efficiency': 0.696747371024361
# Skewness of 'Power_perf_factor': 1.0842229186503125

# %%
numeric_df['Wheelbase'].skew()
# Out:
# 0.9741771849319394

# %% [markdown]
# ## Z-score
#
# Detect Outliers using Z-Score. (Set threshold =3)

# %%
new_df = numeric_df.copy()

# %%
z_scores = new_df.apply(lambda x: np.abs((x - x.mean()) / x.std()))

#  threshold for outliers
threshold = 3

# outliers for each column
outliers_by_column = z_scores > threshold

# count outliers in each column
num_outliers_by_column = outliers_by_column.sum()

# Print columns with outliers and the number of outliers in each column
print("Columns with outliers:")
for col, num_outliers in num_outliers_by_column.items():
    if num_outliers > 0:
        print(f"{col}: {num_outliers} outliers")
# Out:
# Columns with outliers:
# Sales_in_thousands: 2 outliers
# __year_resale_value: 5 outliers
# Price_in_thousands: 4 outliers
# Engine_size: 1 outliers
# Horsepower: 1 outliers
# Wheelbase: 3 outliers
# Curb_weight: 3 outliers
# Fuel_capacity: 4 outliers
# Fuel_efficiency: 1 outliers
# Power_perf_factor: 1 outliers

# %% [markdown]
# ## Remove outliers

# %%
sns.histplot(new_df['Wheelbase'], kde = True)
# Out:
# <Axes: xlabel='Wheelbase', ylabel='Count'>

# %%
wheel_mean = numeric_df['Wheelbase'].mean()
wheel_std = numeric_df['Wheelbase'].std()
print("mean:", wheel_mean, " std:", wheel_std)

upl = wheel_mean + 3*wheel_std
lll = wheel_mean - 3*wheel_std
print("Upper limit:", upl, "Lower limit:", lll)
new_df = new_df.loc[(new_df['Wheelbase'] < upl) & (new_df['Wheelbase']> lll)]
print('before removing outliers:', len(numeric_df))
print('After remving:', len(new_df))

print(sns.boxplot(new_df['Wheelbase']))
# Out:
# mean: 107.48407643312099  std: 7.616871535881416
# Upper limit: 130.33469104076525 Lower limit: 84.63346182547674
# before removing outliers: 157
# After remving: 154
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(new_df['Power_perf_factor'], kde= True)
# Out:
# <Axes: xlabel='Power_perf_factor', ylabel='Count'>

# %%
sns.boxplot(new_df['Power_perf_factor'])
# Out:
# <Axes: ylabel='Power_perf_factor'>

# %%
wheel_mean = new_df['Power_perf_factor'].mean()
wheel_std = new_df['Power_perf_factor'].std()
print("mean:", wheel_mean, " std:", wheel_std)

upl = wheel_mean + 3*wheel_std
lll = wheel_mean - 3*wheel_std
print("Upper limit:", upl, "Lower limit:", lll)
new_df = new_df.loc[(new_df['Power_perf_factor'] < upl) & (new_df['Power_perf_factor']> lll)]
print('before removing outliers:', len(new_df))
#print('After remving:', len(new_df3))

print(sns.boxplot(new_df['Power_perf_factor']))
# Out:
# mean: 76.9906482724026  std: 25.091292090383018
# Upper limit: 152.26452454355166 Lower limit: 1.7167720012535455
# before removing outliers: 153
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(new_df['Fuel_efficiency'], kde= True)
# Out:
# <Axes: xlabel='Fuel_efficiency', ylabel='Count'>

# %%
sns.boxplot(new_df['Fuel_efficiency'])
# Out:
# <Axes: ylabel='Fuel_efficiency'>

# %%
wheel_mean = new_df['Fuel_efficiency'].mean()
wheel_std = new_df['Fuel_efficiency'].std()
print("mean:", wheel_mean, " std:", wheel_std)

upl = wheel_mean + 4*wheel_std
lll = wheel_mean - 2*wheel_std
print("Upper limit:", upl, "Lower limit:", lll)
new_df3 = new_df.loc[(new_df['Fuel_efficiency'] < upl) & (new_df['Fuel_efficiency']> lll)]
print('before removing outliers:', len(new_df))
print('After remving:', len(new_df3))

print(sns.boxplot(new_df3['Fuel_efficiency']))
# Out:
# mean: 24.013071895424837  std: 4.164364689185359
# Upper limit: 40.67053065216628 Lower limit: 15.684342517054118
# before removing outliers: 153
# After remving: 147
# Axes(0.125,0.11;0.775x0.77)

# %%
wheel_mean = new_df['Horsepower'].mean()
wheel_std = new_df['Horsepower'].std()
print("mean:", wheel_mean, " std:", wheel_std)

upl = wheel_mean + 3*wheel_std
lll = wheel_mean - 3*wheel_std
print("Upper limit:", upl, "Lower limit:", lll)
new_df3 = new_df.loc[(new_df['Horsepower'] < upl) & (new_df['Horsepower']> lll)]
print('before removing outliers:', len(new_df))
print('After remving:', len(new_df3))

print(sns.boxplot(new_df3['Horsepower']))
# Out:
# mean: 184.08823529411765  std: 52.60847557938148
# Upper limit: 341.9136620322621 Lower limit: 26.262808555973237
# before removing outliers: 153
# After remving: 152
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(new_df3['Horsepower'], kde= True)
# Out:
# <Axes: xlabel='Horsepower', ylabel='Count'>

# %%
wheel_mean = new_df['Price_in_thousands'].mean()
wheel_std = new_df['Price_in_thousands'].std()
print("mean:", wheel_mean, " std:", wheel_std)

upl = wheel_mean + 3*wheel_std
lll = wheel_mean - 3*wheel_std
print("Upper limit:", upl, "Lower limit:", lll)
new_df3 = new_df.loc[(new_df['Price_in_thousands'] < upl) & (new_df['Price_in_thousands']> lll)]
print('before removing outliers:', len(new_df))
print('After remving:', len(new_df3))

print(sns.boxplot(new_df['Price_in_thousands']))
# Out:
# mean: 27.176895424836598  std: 13.999733623482474
# Upper limit: 69.17609629528403 Lower limit: -14.822305445610827
# before removing outliers: 153
# After remving: 148
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(new_df3['Price_in_thousands'], kde= True)
# Out:
# <Axes: xlabel='Price_in_thousands', ylabel='Count'>

# %%
sns.histplot(new_df3['Sales_in_thousands'], kde= True)
# Out:
# <Axes: xlabel='Sales_in_thousands', ylabel='Count'>

# %%
wheel_mean = new_df['Fuel_efficiency'].mean()
wheel_std = new_df['Fuel_efficiency'].std()
print("mean:", wheel_mean, " std:", wheel_std)

upl = wheel_mean + 3*wheel_std
lll = wheel_mean - 1*wheel_std
print("Upper limit:", upl, "Lower limit:", lll)
new_df3 = new_df.loc[(new_df['Fuel_efficiency'] < upl) & (new_df['Fuel_efficiency']> lll)]
print('before removing outliers:', len(new_df))
print('After remving:', len(new_df3))

print(sns.boxplot(new_df['Fuel_efficiency']))
# Out:
# mean: 24.013071895424837  std: 4.164364689185359
# Upper limit: 36.506165962980916 Lower limit: 19.848707206239478
# before removing outliers: 153
# After remving: 134
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(new_df3['Fuel_efficiency'], kde= True)
# Out:
# <Axes: xlabel='Fuel_efficiency', ylabel='Count'>

# %%
wheel_mean = new_df['__year_resale_value'].mean()
wheel_std = new_df['__year_resale_value'].std()
print("mean:", wheel_mean, " std:", wheel_std)

upl = wheel_mean + 2*wheel_std
lll = wheel_mean - 2*wheel_std
print("Upper limit:", upl, "Lower limit:", lll)
new_df3 = new_df.loc[(new_df['__year_resale_value'] < upl) & (new_df['__year_resale_value']> lll)]
print('before removing outliers:', len(new_df))
print('After remving:', len(new_df3))
# Out:
# mean: 16.976764705882353  std: 9.73562750509471
# Upper limit: 36.44801971607177 Lower limit: -2.4944903043070674
# before removing outliers: 153
# After remving: 145

# %%
sns.histplot(new_df3['__year_resale_value'], kde= True)
# Out:
# <Axes: xlabel='__year_resale_value', ylabel='Count'>

# %%
z_scores = new_df3.apply(lambda x: np.abs((x - x.mean()) / x.std()))

#  threshold for outliers
threshold = 4

# outliers for each column
outliers_by_column = z_scores > threshold

# count outliers in each column
num_outliers_by_column = outliers_by_column.sum()

# Print columns with outliers and the number of outliers in each column
print("Columns with outliers:")
for col, num_outliers in num_outliers_by_column.items():
    if num_outliers > 0:
        print(f"{col}: {num_outliers} outliers")
# Out:
# Columns with outliers:
# Sales_in_thousands: 1 outliers
# Price_in_thousands: 1 outliers
# Fuel_efficiency: 1 outliers

# %%
#Final checks for dataset 'new_df3', after removal of outliers, missing values.

print("Duplicate values:",new_df3.duplicated().sum())
print("Missing values:", new_df3.isna().sum())
print('Previous Shape:', df.shape)
print('Dataset shape after cleaning:', new_df3.shape )
# Out:
# Duplicate values: 0
# Missing values: Sales_in_thousands     0
# __year_resale_value    0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Power_perf_factor      0
# dtype: int64
# Previous Shape: (157, 16)
# Dataset shape after cleaning: (145, 12)

# %% [markdown]
# ## Distribution Check

# %%
sns.histplot(new_df3, kde = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:160: UserWarning: The label '__year_resale_value' of <matplotlib.patches.Patch object at 0x7e029b0434c0> starts with '_'. It is thus excluded from the legend.
#   ax_obj.legend(handles, labels, title=self.variables["hue"], **legend_kws)
# <Axes: ylabel='Count'>

# %%
log_transformed_data = np.log(new_df3)
print(log_transformed_data)
# Out:
#      Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0              2.828437             2.794839            3.068053     0.587787
# 1              3.673360             2.989463            3.346389     1.163151
# 2              2.647167             2.902794            3.126717     1.163151
# 3              2.150366             3.391988            3.737670     1.252763
# 4              3.015388             3.102567            3.177637     0.587787
# ..                  ...                  ...                 ...          ...
# 152            1.265538             2.651833            3.194583     0.641854
# 153            2.724252             2.651833            3.314186     0.875469
# 154            2.863971             2.651833            3.360375     0.875469
# 155            1.250761             2.651833            3.817712     0.832909
# 156            2.942806             2.651833            3.583519     1.064711
#
# ...

# %% [markdown]
# #### Use binning technique to remove Skewness

# %%
log_transformed_data = np.log10(new_df3)
print(log_transformed_data)
# Out:
#      Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0              1.228375             1.213783            1.332438     0.255273
# 1              1.595320             1.298307            1.453318     0.505150
# 2              1.149650             1.260668            1.357916     0.505150
# 3              0.933892             1.473122            1.623249     0.544068
# 4              1.309566             1.347428            1.380030     0.255273
# ..                  ...                  ...                 ...          ...
# 152            0.549616             1.151676            1.387390     0.278754
# 153            1.183127             1.151676            1.439333     0.380211
# 154            1.243807             1.151676            1.459392     0.380211
# 155            0.543199             1.151676            1.658011     0.361728
# 156            1.278044             1.151676            1.556303     0.462398
#
# ...

# %%
base = 2
log_custom_base_transformed_data = np.log(new_df3) / np.log(base)

# %%
new_df3['Length'] =  np.log(new_df3['Length'])
# Out:
# <ipython-input-62-2894978d29d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df3['Length'] =  np.log(new_df3['Length'])

# %%
for col in log_custom_base_transformed_data:
    skewness = log_custom_base_transformed_data[col].skew()
    print(f"Skewness of '{col}': {skewness}")

#Skewness removed
# Out:
# Skewness of 'Sales_in_thousands': -0.9948276385556878
# Skewness of '__year_resale_value': 0.19528596136888093
# Skewness of 'Price_in_thousands': 0.23618479745500082
# Skewness of 'Engine_size': -0.031063935174634943
# Skewness of 'Horsepower': -0.4511972353594007
# Skewness of 'Wheelbase': 0.01233388932564669
# Skewness of 'Width': 0.37282589728782534
# Skewness of 'Length': -0.5703180939667719
# Skewness of 'Curb_weight': 0.0909712742401512
# Skewness of 'Fuel_capacity': 0.4807254603227777
# Skewness of 'Fuel_efficiency': -0.32662378430784583
# Skewness of 'Power_perf_factor': -0.33333496914480104

# %%
for col in numeric_df:
    skewness = numeric_df[col].skew()
    print(f"Skewness of '{col}': {skewness}")

#Skew is not processed in dataset,
# Out:
# Skewness of 'Sales_in_thousands': 3.408518366470572
# Skewness of '__year_resale_value': 2.7596078613149624
# Skewness of 'Price_in_thousands': 1.7853991263500237
# Skewness of 'Engine_size': 1.1049946829756925
# Skewness of 'Horsepower': 1.0064919298234107
# Skewness of 'Wheelbase': 0.9741771849319394
# Skewness of 'Width': 0.48857960000426515
# Skewness of 'Length': -0.060034999150741744
# Skewness of 'Curb_weight': 0.7148020333191302
# Skewness of 'Fuel_capacity': 1.143576428561609
# Skewness of 'Fuel_efficiency': 0.696747371024361
# Skewness of 'Power_perf_factor': 1.0842229186503125

# %% [markdown]
# ## Distribution check
# To confirm if skewness is removed or not

# %% [markdown]
# ### Standardization and Normalization

# %% [markdown]
# Apply standardization and normalization on the columns

# %% [markdown]
# ## Standardization

# %%
scaler_standrizer = StandardScaler()
skew_removed = log_custom_base_transformed_data

skew_removed = scaler_standrizer.fit_transform(skew_removed)
print(skew_removed)
# Out:
# [[-0.44922109  0.39984828 -0.19133106 ... -1.34685158  0.93101074
#   -0.67272406]
#  [ 0.2526605   0.98184735  0.50633617 ... -0.03148396  0.28757244
#    0.88709183]
#  [-0.59980309  0.72267534 -0.0442867  ... -0.03148396  0.51025312
#    0.06209514]
#  ...
#  [-0.41970323 -0.02779742  0.54139357 ...  0.16675268  0.28757244
#    0.01970203]
#  [-1.7598053  -0.02779742  1.6877374  ...  0.33059445 -0.18583746
#    1.25599564]
#  [-0.3542143  -0.02779742  1.10071693 ...  0.98408423  0.05580027
#    0.66627572]]

# %% [markdown]
# ## Normalization

# %%
scaler = MinMaxScaler()
log_custom_base_transformed_data = scaler.fit_transform(log_custom_base_transformed_data)
print(log_custom_base_transformed_data)
# Out:
# [[0.64309945 0.59210545 0.37971078 ... 0.21883794 0.56812974 0.50924587]
#  [0.75100258 0.69197309 0.50477671 ... 0.45233689 0.46497352 0.7587369 ]
#  [0.61994986 0.64750069 0.40607039 ... 0.45233689 0.50067375 0.62677949]
#  ...
#  [0.64763735 0.51872396 0.51106121 ... 0.48752709 0.46497352 0.61999875]
#  [0.44161796 0.51872396 0.71655826 ... 0.51661165 0.38907631 0.81774271]
#  [0.65770523 0.51872396 0.6113272  ... 0.63261662 0.42781574 0.72341758]]

# %% [markdown]
# ## Distribution check

# %%
sns.distplot(skew_removed)
# Out:
# <ipython-input-68-cfec1188ec64>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(skew_removed)
# <Axes: ylabel='Density'>

# %% [markdown]
# ## The END!
